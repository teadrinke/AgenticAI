# %%
from typing_extensions import TypedDict

class PortfolioState(TypedDict):
    amount_usd: float
    total_usd: float
    total_inr: float

# %%
myobj : PortfolioState = {
    'amount_usd': 100.0,
    'total_usd': 1000.0,    
    'total_inr': 75000.0
}

# %%
def calc_total(state: PortfolioState) -> PortfolioState:
    state['total_usd'] = state['amount_usd']*1.08
    return state

def convert_to_inr(state: PortfolioState) -> PortfolioState:
    state['total_inr'] = state['total_usd']*91.0
    return state

# %%
from langgraph.graph import StateGraph, START, END

builder = StateGraph(PortfolioState)

builder.add_node("calc_total_node", calc_total)
builder.add_node("convert_to_inr_node", convert_to_inr)

builder.add_edge(START, "calc_total_node")
builder.add_edge("calc_total_node", "convert_to_inr_node")  
builder.add_edge("convert_to_inr_node", END)

graph = builder.compile()

# %%
from IPython.display import Markdown
Markdown(f"```mermaid\n{graph.get_graph().draw_mermaid()}\n```")
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	calc_total_node(calc_total_node)
# 	convert_to_inr_node(convert_to_inr_node)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> calc_total_node;
# 	calc_total_node --> convert_to_inr_node;
# 	convert_to_inr_node --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```

# %%
graph.invoke({"amount_usd": 1000})
# Out:
# {'amount_usd': 1000, 'total_usd': 1080.0, 'total_inr': 98280.0}
